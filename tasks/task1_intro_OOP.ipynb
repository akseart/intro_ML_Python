# %% [markdown]
# # Введение в методы анализа данных. Язык Python.

# %% [markdown]
# ## Домашняя работа 1: Процедурный подход к написанию программ. ООП. Паттерны проектирвания
# <br><br><br><br>
# __Ксемидов Борис (nstalker.anonim@yandex.ru)__
#
# __Аксентьев Артем (akseart@ya.ru)__
#
#
# <br>

# %% [markdown]
# __Выдана__: 19.02.2020
# __Deadline__: 23:59 26.02.2020
#
# Готовые решения отправлять на почту akseart@ya.ru и nstalker.anonim@yandex.ru

# %% [markdown]
# __ФИО:__ ...

# %% [markdown]
# ## Критерии оценивания:
# - Правильность исполнения кода
# - Корректное исполнение на граничных случаях
# - Соблюдение PEP-8 и именования переменных
#
# Всего за работу можно получить 20 баллов и 5 бонусных.
#
# Изменение формулировок заданий, удаление фрагментов заданий запрещено.
#
# Все ячейки должны быть "выполненными". Под каждую задачу выполнена проверка.
#
# При заимствовании кода из интернета, необходимо указать ссылку на ресурс.

# %% [markdown]
# # Зачет
#
# Для выставления оценки за зачет, необходимо руководствоваться следующей таблицей:
#
# | Оценка | Необходимый балл |
# |--------|------------------|
# | 5      | 75               |
# | 4      | 65               |
# | 3      | 55               |

# %% [markdown]
# **Задание 1.** (2 балла)
#
# Реализуйте функцию на вход которой дан массив целых чисел. Для данного массива определена операция прибавления к первым k элементам единицы и только она. Определить возможно ли уравнять все значения в массиве и если возможно за какое количество шагов?
#
# Функция должна возвращать кортеж значений, первый элемент которого показывает возможно ли выполнить заданное условие, а второй элемент либо None, если невозможно, либо количество шагов для достижения заданного условия.

# %%
def task_01(array):
    ...

task_01([])

# %% [markdown]
# __Задание 2.__  (2 балла)
#
# Необходимо написать функцию, которая будет принимать две строки и определять можно ли составить из символов первой строки вторую строку.

# %%
def is_anagram(str1, str2):
    ...

is_anagram("", "")

# %% [markdown]
# **Задание 3.** (2 баллов)
#
# На основе заданного текстового файла создать новый файл, который будет содержать в каждой строке количество символов и количество слов в строке из первого файла, а также в конце файла необходимо дописать количество строк.
#
# __Примечание:__  в качестве разделителя слов может выступать символ пробела, запятой, а также точки. В подсчет символов входят так же символы разделители, но не входят скрытые символы, такие как символ переноса строки, в том числе пробельные символы в конце строки

# %%
def get_info_for_file(path_to_file1, path_to_file2):
    ...

get_info_for_file("", "")

# %% [markdown]
# **Задание 4.** (3 балла)
#
# В некоторой компании используется git сервер для обмена кодом между разными членами команды. В рамках системы git существует понятие коммита, некоего "снимка" состояния кода в определенный момент времени. Также как и в любой хорошей компании существует набор тестов, однако тесты достаточно сложны, чтобы их запускать для каждого коммита, поэтому их запускают с некоторой регулярностью и проверяют сразу набор коммитов. Известно, что коммит который сломал тест, так же ломает тесты и всех последующих за ним коммитов.
#
# Ваша задача имитировать систему поиска ломающего коммита.
#
# На __вход функции__ подается массив состояний коммитов состоящий из логических элементов, где значение True обозначет, что данный коммит не ломает тест, а значени False, соответственно ломает. Гарантируется, что существует хотя бы один не ломающий коммит и хотя бы один ломающий
#
# На __выходе функции__ должен быть <u>номер  первого ломающего</u> коммита. За каждый шаг работы функция может проверить одновременно 2 элемента.
#
# __Примечание:__ Количество коммитов для проверки может быть очень большим ($10^6$), а количество шагов выполняемой вашей программой ограничено 25.

# %% [markdown]
# __Пример входных и выходных данных:__
# [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False] -> 6

# %%
def find_breaking_commit(commits):
    ...

find_breaking_commit([])

# %% [markdown]
# **Задание 4. Бонус**(5 баллов)
#
# Подумайте, как можно улучшить вашу функцию, так что бы она принимала на вход описанный выше массив, а так же количество одновременно выполняемых запросов. При этом количество шагов выполняемых Вашей программой должно быть минимально

# %%
def find_breaking_commit_any_request(commits, num_request):
    ...
find_breaking_commit_any_request([], 0)

# %% [markdown]
# # Для выполнения дальнейших заданий необходимо использовать следующий интерфейс:

# %%
from abc import ABC, abstractmethod

class IContainer(ABC):
    @abstractmethod
    def shape(self):
        ...

    @abstractmethod
    def __add__(self, other):
        pass

    @abstractmethod
    def __mul__(self, other):
        pass

    @abstractmethod
    def __str__(self):
        pass

    @abstractmethod
    def __repr__(self):
        pass

    @abstractmethod
    def __setitem__(self, key, value):
        pass

    @abstractmethod
    def __getitem__(self, item):
        pass

# %% [markdown]
# **Задание 5.** (2 балла)
#
# Реализуйте на основе заданного интерфейса (IContainer) класс для одномерного вектора целых чисел (int).

# %%
class Vector(IContainer):
    pass

Vector()

# %% [markdown]
# **Задание 6.**  (5 балла)
#
# Реализуйте на основе заданного интерфейса (IContainer) класс для двумерной матрицы целых чисел (int).

# %%
class Matrix(IContainer):
    pass

Matrix()

# %% [markdown]
# **Задание 7.**  (5 балла)
#
# Реализовать чат-бота, отвечающий на заранее подготовленные фразы. Допускается создание любого кол-ва классов для решения задания. Спроектируйте решение таким образом, чтобы Ваша реализация была легко модифицируемой.
#
# Примеры.
#
# Запрос: Привет.
# Ответ: Привет, друг.
#
# Запрос: Как дела?
# Ответ: Всё хорошо.
